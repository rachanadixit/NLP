# %%
# !pip install gensim

# Step 2: Import Libraries
import numpy as np
import re
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# %%
documents = [
    # Laptops / Programming
    "best laptop for coding and programming",
    "top programming laptops for developers",
    "best laptop for software engineering students",
    "which laptop is good for python development",
    "high performance laptop for coding tasks",

    # Smartphones
    "best smartphones under budget",
    "cheap mobile phones with good battery",
    "top android phones for gaming",
    "latest iphone features and performance",
    "budget phones with best camera quality",

    # Machine Learning / AI
    "learn machine learning and artificial intelligence",
    "deep learning tutorials and AI courses",
    "best resources to study machine learning",
    "python libraries for machine learning",
    "introduction to neural networks and deep learning",

    # Cooking / Food
    "how to cook healthy food at home",
    "easy recipes for beginners cooking",
    "quick dinner recipes for students",
    "healthy breakfast ideas at home",
    "vegetarian recipes for weight loss",

    # Cybersecurity
    "cybersecurity and ethical hacking basics",
    "network security and penetration testing",
    "how to learn ethical hacking",
    "tools used in cybersecurity analysis",
    "introduction to network vulnerabilities",

    # Data Science
    "data science projects for beginners",
    "how to become a data scientist",
    "data analysis using python pandas",
    "best tools for data visualization",
    "statistics concepts for data science",

    # Cloud / DevOps
    "what is cloud computing and AWS",
    "docker and kubernetes tutorial",
    "CI CD pipeline explained",
    "devops tools and practices",
    "cloud engineer roles and responsibilities",

    # Education / Courses
    "best online courses for programming",
    "top websites to learn coding",
    "free resources for learning python",
    "how to prepare for coding interviews",
    "beginner guide to software development"
]

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = text.split()

    # remove stopwords
    words = [w for w in words if w not in ENGLISH_STOP_WORDS]

    # lemmatization
    words = [lemmatizer.lemmatize(w) for w in words]

    return words
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
model = Word2Vec(sentences=processed_docs, vector_size=50, window=3, min_count=1)

# %%
def get_sentence_vector(sentence):
    words = preprocess(sentence)
    vectors = []

    for word in words:
        if word in model.wv:
            vectors.append(model.wv[word])

    if len(vectors) == 0:
        return np.zeros(50)

    return np.mean(vectors, axis=0)

# %%
doc_vectors = [get_sentence_vector(doc) for doc in documents]

# %%
query = input("Enter your search query: ")
query_vector = get_sentence_vector(query)
# Out:
# Enter your search query: best laptop for programming

# %%
similarities = []

for vec in doc_vectors:
    sim = cosine_similarity([query_vector], [vec])[0][0]
    similarities.append(sim)

# %%
for i in top_indices[:5]:
    if similarities[i] > 0.4:   # threshold
        print("Sentence:", documents[i])
        print("Similarity:", round(similarities[i], 3))
        print("-" * 50)
# Out:
# Sentence: best laptop for coding and programming
# Similarity: 0.801
# --------------------------------------------------
# Sentence: best online courses for programming
# Similarity: 0.591
# --------------------------------------------------
# Sentence: best laptop for software engineering students
# Similarity: 0.445
# --------------------------------------------------
# Sentence: top programming laptops for developers
# Similarity: 0.773
# --------------------------------------------------
